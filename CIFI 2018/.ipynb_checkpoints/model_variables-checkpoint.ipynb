# %% [markdown]
# # Bases de datos

# %%
import pandas as pd
#import pandas_datareader.data as web
import numpy as np
import datetime
import matplotlib.pyplot as plt
import scipy.stats as st
import openpyxl
import pandas.io.formats.excel 
import time
# %matplotlib inline
#pd.set_option('display.notebook_repr_html', True)
#pd.set_option('display.max_columns', 11)
#pd.set_option('display.max_rows', 10)
#pd.set_option('display.width', 78)
pd.set_option('precision', 3)
pd.options.display.float_format = '{:.5f}'.format

# %%
data=pd.read_excel('annual_generation_state.xls','TOTALES',index_col=0)
data=data.loc[data['GENERATION (Megawatthours)']>0,:]

# %%
years=np.unique(data.index)

# %%
states=np.unique(data['STATE'])
states
# Out:
# array(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
#        'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
#        'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
#        'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'US-TOTAL', 'US-Total', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY'],
#       dtype=object)

# %%
energies=np.unique(data['ENERGY SOURCE'])
energies
# Out:
# array(['Coal', 'Geothermal', 'Hydroelectric Conventional', 'Natural Gas',
#        'Nuclear', 'Other', 'Other Biomass', 'Other Gases', 'Petroleum',
#        'Pumped Storage', 'Solar Thermal and Photovoltaic', 'Wind',
#        'Wood and Wood Derived Fuels'], dtype=object)

# %%
total_by_states=list(map(lambda s:list(map(lambda y:sum(data.loc[data['STATE']==states[s],'GENERATION (Megawatthours)'].loc[data.loc[data['STATE']==states[s],:].index==years[y]]),range(len(years)))),range(len(states))))

# %%
data_by_states=list(map(lambda e:data.loc[data['STATE']==states[e],:],range(len(states))))

# %%
data_by_states=list(map(lambda s:list(map(lambda y:(data.loc[data['STATE']==states[s],:].loc[data.loc[data['STATE']==states[s],:].index==years[y]]),range(len(years)))),range(len(states))))

# %%
#state,year
proportions_by_states=list(map(lambda s:list(map(lambda y:pd.concat([data_by_states[s][y],data_by_states[s][y]['GENERATION (Megawatthours)']/total_by_states[s][y]],axis=1),range(len(years)))),range(len(states))))

# %%
#state,type of energy
df=list(map(lambda s:list(map(lambda e:pd.DataFrame(np.reshape((np.column_stack(list(map(lambda y:pd.DataFrame(np.ones([1,4])*.0001) if (proportions_by_states[s][y].loc[proportions_by_states[s][y]['ENERGY SOURCE']==energies[e],:]).empty else proportions_by_states[s][y].loc[proportions_by_states[s][y]['ENERGY SOURCE']==energies[e],:],range(len(years)))))),(28,4))),range(len(energies)))),range(len(states))))

# %%
#state,type of energy
df_with_ret=list(map(lambda s:list(map(lambda e:pd.concat([df[s][e],(df[s][e][3]/df[s][e][3].shift(1)-1)*100],axis=1),range(len(energies)))),range(len(states))))

# %%
df_with_rets=list(map(lambda s:list(map(lambda e:pd.concat([df_with_ret[s][e],(df[s][e][2]/df[s][e][2].shift(1)-1)*100],axis=1),range(len(energies)))),range(len(states))))

# %%
df_with_rets_dates=list(map(lambda s:list(map(lambda e:df_with_rets[s][e].set_index(years),range(len(energies)))),range(len(states))))

# %%
#El codigo queda comentado para que cada vez que se corra todo no afecte el primer archivo ya generado

#doc=openpyxl.load_workbook('database.xlsx')
#hoja=doc.get_sheet_by_name('Hoja1')
#list(map(lambda s:list(map(lambda e:list(map(lambda f: hoja.append([""]) if pd.DataFrame.equals(df_with_rets_dates[s][e],df_with_rets_dates[0][5]) else hoja.append([df_with_rets_dates[s][e].index[f],df_with_rets_dates[s][e].iloc[f,0],df_with_rets_dates[s][e].iloc[f,1],df_with_rets_dates[s][e].iloc[f,2],df_with_rets_dates[s][e].iloc[f,3],df_with_rets_dates[s][e].iloc[f,4],df_with_rets_dates[s][e].iloc[f,5]]),range(28))),range(len(energies)))),range(len(states))))
#doc.save('database.xlsx')

# %%
df_total_by_state=pd.DataFrame(np.reshape(total_by_states,[53,28]).T).set_index(years)
df_total_by_state.columns=states
df_total_by_state=pd.concat([df_total_by_state,df_total_by_state/df_total_by_state.shift(1)-1],axis=1)
df_total_by_state
# Out:
#                 AK              AL             AR              AZ  \
# 1990 5599506.00000  79652133.00000 39099598.00000  62774297.00000
# 1991 5389828.00000  88786612.00000 40651244.00000  67202551.00000
# 1992 5298424.00000  95234422.00000 39746101.00000  70552727.00000
# 1993 5721277.00000  99336996.00000 40498654.00000  68468986.00000
# 1994 5966516.00000 100764257.00000 42032148.00000  71934496.00000
# 1995 6026116.00000 105189366.00000 41972088.00000  69780939.00000
# 1996 6128892.00000 121472911.00000 46033563.00000  71654818.00000
# 1997 6154847.00000 119542332.00000 45193600.00000  78825200.00000
# 1998 5828845.00000 119862125.00000 45665301.00000  82095072.00000
# 1999 5802308.00000 120657508.00000 46553939.00000  83893173.00000
# 2000 6156525.00000 124405340.00000 43875766.00000  88946577.00000
# 2001 6743766.00000 125345113.00000 47192035.00000  89911272.00000
# 2002 6767325.00000 132920670.00000 47611644.00000  94131666.00000
# 2003 6338733.00000 137487222.00000 50401101.00000  94396218.00000
# 2004 6526718.00000 137354770.00000 51927632.00000 104617584.00000
# 2005 6576660.00000 137948581.00000 47794510.00000 101478654.00000
# 2006 6674197.00000 140895442.00000 52168703.00000 104392527.00000
# 2007 6821391.00000 143826270.00000 54596236.00000 113340971.00000
# 2008 6774835.00000 145869896.00000 55050527.00000 119459171.00000
# 2009 6702159.00000 143255557.00000 57457740.00000 111971250.00000
# 2010 6759575.00000 152150512.00000 61000705.00000 111750957.00000
# 2011 6871032.79000 156339209.84000 61307535.88000 108125356.89000
# 2012 6946418.00000 152878687.00000 65005678.00000 110904993.00000
# 2013 6497078.64000 150572923.85000 60322492.15000 113325986.12000
# 2014 6045142.63000 149340447.08000 61592136.66000 112257187.46000
# 2015 6287344.00000 152477426.00000 55559428.00000 113142047.00000
# 2016 6337426.00000 142385098.00000 60445059.00000 108763450.00000
# 2017 6500176.00000 139964250.00000 60775299.00000 105898737.00000
#
#                   CA             CO             CT           DC            DE  \
# 1990 165784909.00000 32581325.00000 35147247.00000 361043.00000 7841500.00000
# 1991 158947642.00000 32339723.00000 27040023.00000 179814.00000 7838132.00000
# 1992 177159954.00000 33295490.00000 29211380.00000  73991.00000 6984285.00000
# 1993 186990642.00000 34240183.00000 32888825.00000 188452.00000 9017680.00000
# 1994 186191991.00000 35651911.00000 31178917.00000 274252.00000 9230276.00000
# 1995 181463341.00000 35617234.00000 31484882.00000 188862.00000 9032837.00000
# 1996 175263204.00000 37257452.00000 20211398.00000 109809.00000 8854449.00000
# 1997 172797595.00000 37642561.00000 17806462.00000  70661.00000 7222635.00000
# 1998 189600706.00000 38881563.00000 19691492.00000 243975.00000 6898585.00000
# 1999 188705437.00000 39521288.00000 28596898.00000 230003.00000 6851738.00000
# 2000 208082483.00000 44165546.00000 32971938.00000 144374.00000 5987451.00000
# 2001 198945764.00000 47126584.00000 30490646.00000 123239.00000 6807684.00000
# 2002 184451028.00000 45820652.00000 31321419.00000 261980.00000 6002489.00000
# 2003 193700856.00000 46820427.00000 29545069.00000  74144.00000 7392287.00000
# 2004 195597185.00000 48061293.00000 32633407.00000  36487.00000 7855552.00000
# 2005 200292817.00000 49738758.00000 33551400.00000 226042.00000 8136568.00000
# 2006 216798688.00000 50898855.00000 34681736.00000  81467.00000 7182180.00000
# 2007 210847580.00000 54075553.00000 33186566.00000  75251.00000 8534163.00000
# 2008 207984263.00000 53690702.00000 30409472.00000  72316.00000 7523839.00000
# 2009 204776132.00000 50674609.00000 31206222.00000  35499.00000 4841563.00000
# 2010 204296860.00000 50841585.00000 33349623.00000 199858.00000 5627645.00000
# 2011 200893635.49000 51675933.29000 33745220.60000 200873.96000 6590194.80000
# 2012 199518568.00000 52801168.00000 36117544.00000  71787.00000 8633694.00000
# 2013 200077114.63000 53217868.91000 35611840.33000  65852.08000 7760861.00000
# 2014 198912361.78000 54072649.92000 33676980.41000  67612.16000 7703583.52000
# 2015 196703858.00000 52671601.00000 37474329.00000  53750.00000 7810006.00000
# 2016 197222564.00000 54712666.00000 36496560.00000  76474.00000 8731261.00000
# 2017 206146392.00000 54170657.00000 34562654.00000  66871.00000 7495976.00000
#
#                   FL   ...          TX  US-TOTAL  US-Total       UT       VA  \
# 1990 131502553.00000   ...         nan       nan       nan      nan      nan
# 1991 139416689.00000   ...     0.01694   0.01217       nan -0.06319  0.04436
# 1992 143777143.00000   ...     0.01384   0.00316       nan  0.08953  0.02242
# 1993 151934156.00000   ...     0.03237   0.03665       nan  0.02470  0.08770
# 1994 158146846.00000   ...     0.02500   0.01552       nan  0.03343  0.01247
# 1995 167414372.00000   ...     0.03404   0.03239       nan -0.06789  0.01550
# 1996 167084936.00000   ...     0.03562   0.02713       nan  0.00440  0.06211
# 1997 168246993.00000   ...     0.02241   0.01420       nan  0.05342  0.02443
# 1998 189628996.00000   ...     0.05650   0.03677       nan  0.03452  0.05442
# 1999 187263426.00000   ...     0.01020   0.02101       nan  0.02434  0.02694
# 2000 191815840.00000   ...     0.05237   0.02884       nan -0.00477  0.04532
# 2001 190945344.00000   ...    -0.01367  -0.01633       nan -0.02063 -0.02783
# 2002 203352775.00000   ...     0.03502   0.03250       nan  0.02104  0.00851
# 2003 212610011.00000   ...    -0.01667   0.00634       nan  0.03867 -0.00243
# 2004 218117927.00000   ...     0.02927   0.02244       nan  0.00495  0.04243
# 2005 220256412.00000   ...     0.01632   0.02084       nan -0.00123  0.00372
# 2006 223751621.00000   ...     0.00987   0.00228       nan  0.08118 -0.07624
# 2007 225416059.00000   ...     0.01226   0.02269       nan  0.09959  0.07737
# 2008 219636819.00000   ...    -0.00174  -0.00912       nan  0.02658 -0.07082
# 2009 217952309.00000   ...    -0.01882  -0.04138       nan -0.06518 -0.03901
# 2010 229095935.00000   ...     0.03658   0.04440       nan -0.02971  0.04257
# 2011 221894574.08000   ...     0.05777  -0.00581       nan -0.03345 -0.08484
# 2012 221096136.00000   ...    -0.01301  -1.00000       inf -0.03510  0.05818
# 2013 222398923.97000   ...     0.00830       nan   0.00442  0.07902  0.08295
# 2014 230015937.30000   ...     0.00981       nan   0.00716  0.02982  0.00445
# 2015 237412633.00000   ...     0.02787       nan  -0.00417 -0.04192  0.08944
# 2016 238262151.00000   ...     0.00938       nan   0.00016 -0.09095  0.09678
# 2017 238413148.00000   ...    -0.00276       nan  -0.01043 -0.01893 -0.02158
#
#            VT       WA       WI       WV       WY
# 1990      nan      nan      nan      nan      nan
# 1991  0.04335  0.00783  0.03324 -0.07689 -0.01693
# 1992 -0.09611 -0.15931 -0.00939  0.02365  0.08080
# 1993 -0.04648  0.01750  0.02751 -0.00547 -0.04008
# 1994  0.20959  0.00671  0.04221  0.08937  0.05472
# 1995 -0.08135  0.15365  0.02987 -0.01096 -0.06397
# 1996  0.03683  0.16107  0.00917  0.08328  0.03032
# 1997  0.06176  0.02923 -0.05520  0.04911 -0.00151
# 1998 -0.12926 -0.16350  0.09790  0.01413  0.09509
# 1999  0.15310  0.14610  0.03705  0.02015 -0.03781
# 2000  0.10510 -0.07556  0.01889 -0.01930  0.04267
# 2001 -0.13048 -0.23271 -0.01477 -0.11876 -0.01577
# 2002 -0.00446  0.23746 -0.00565  0.15794 -0.02218
# 2003  0.10479 -0.02600  0.02894 -0.00053 -0.00359
# 2004 -0.09250  0.02075  0.00536 -0.05239  0.02707
# 2005  0.04504 -0.00205  0.02283  0.04319  0.01695
# 2006  0.23922  0.06117 -0.00299  0.00202 -0.00366
# 2007 -0.17796 -0.01121  0.02840  0.00125  0.00513
# 2008  0.17114  0.03587  0.00140 -0.02991  0.01900
# 2009  0.06776 -0.05737 -0.05546 -0.22322 -0.01013
# 2010 -0.09095 -0.00955  0.07263  0.14136  0.04541
# 2011  0.02360  0.11394 -0.01593 -0.02215 -0.00999
# 2012 -0.02427  0.01365  0.00729 -0.07071  0.04094
# 2013  0.04131 -0.02279  0.03470  0.03337  0.05837
# 2014  0.02128  0.01897 -0.07425  0.06850 -0.05310
# 2015 -0.71811 -0.06061  0.08672 -0.10812 -0.01468
# 2016 -0.03574  0.04393 -0.02100  0.05063 -0.04717
# 2017  0.12044  0.01598  0.00216 -0.03403  0.00183
#
# [28 rows x 106 columns]

# %%
## Grafica (falta un auste al contador)
cont=1
plt.plot(df_with_rets_dates[0][0+cont].iloc[1:27,5],'r')
plt.plot(df_total_by_state.iloc[1:27,53+cont]*100,'b')
plt.show()
